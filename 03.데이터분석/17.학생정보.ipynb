# %%
import pandas as pd

# %%
score = pd.read_csv('data/학생정보.csv', index_col='지원번호')
score
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1     채치수  북산고  197      Python
# 2     정대만  북산고  184        Java
# 3     송태섭  북산고  168  Javascript
# 4     서태웅  북산고  187         NaN
# 5     강백호  북산고  188         NaN
# 6     변덕규  능남고  202           C
# 7     황태산  능남고  188      PYTHON
# 8     윤대협  능남고  190          C#
# 9     홍길동  NaN    0         NaN

# %%
score.loc['4번', 'SW특기'] = 'Java'
score
# Out:
#        이름   학교      키        SW특기
# 지원번호
# 1     채치수  북산고  197.0      Python
# 2     정대만  북산고  184.0        Java
# 3     송태섭  북산고  168.0  Javascript
# 4     서태웅  북산고  187.0         NaN
# 5     강백호  북산고  188.0         NaN
# 6     변덕규  능남고  202.0           C
# 7     황태산  능남고  188.0      PYTHON
# 8     윤대협  능남고  190.0          C#
# 9     홍길동  NaN    0.0         NaN
# 4번    NaN  NaN    NaN        Java

# %%
score.loc['10번', '이름'] = '홍길동'
df = score.copy()
df
# Out:
#        이름   학교      키        SW특기
# 지원번호
# 1     채치수  북산고  197.0      Python
# 2     정대만  북산고  184.0        Java
# 3     송태섭  북산고  168.0  Javascript
# 4     서태웅  북산고  187.0         NaN
# 5     강백호  북산고  188.0         NaN
# 6     변덕규  능남고  202.0           C
# 7     황태산  능남고  188.0      PYTHON
# 8     윤대협  능남고  190.0          C#
# 9     홍길동  NaN    0.0         NaN
# 4번    NaN  NaN    NaN        Java
# 10번   홍길동  NaN    NaN         NaN

# %%
df.index.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df.index.max()
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:7597, in Index.max(self, axis, skipna, *args, **kwargs)
#    7594 if not self._is_multi and not isinstance(self._values, np.ndarray):
#    7595     return self._values._reduce(name="max", skipna=skipna)
# -> 7597 return nanops.nanmax(self._values, skipna=skipna)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1098, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1093     return _na_for_min_count(values, axis)
#    1095 values, mask = _get_values(
#    1096     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097 )
# -> 1098 result = getattr(values, meth)(axis)
#    1099 result = _maybe_null_out(result, axis, mask, values.shape)
#    1100 return result
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_core\_methods.py:44, in _amax(a, axis, out, keepdims, initial, where)
#      42 def _amax(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '>=' not supported between instances of 'int' and 'str'

# %%
df.reset_index(inplace=True)
df
# Out:
#   지원번호   이름   학교   학년      키        SW특기
# 0   1번  채치수  북산고  3.0  197.0      Python
# 1   2번  정대만  북산고  3.0  184.0        Java
# 2   3번  송태섭  북산고  3.0  168.0  Javascript
# 3   4번  서태웅  북산고  1.0  187.0        Java
# 4   5번  강백호  북산고  1.0  188.0         NaN
# 5   6번  변덕규  능남고  3.0  202.0           C
# 6   7번  황태산  능남고  2.0  188.0      Python
# 7   8번  윤대협  능남고  2.0  190.0          C#
# 8  10번  홍길동  NaN  NaN    NaN         NaN

# %%
def change_no(no):
    no = no.replace('번', '')
    no = int(no)
    no = f'{no:02d}'
    
    return no

# %%
no = change_no('2번')
no
# Out:
# '02'

# %%
df2 = score.copy()
df2.reset_index(inplace=True)
df2['지원번호'] = df2['지원번호'].apply(change_no)
df2.set_index('지원번호', inplace=True)
df2
# Out:
#        이름   학교   학년      키        SW특기
# 지원번호
# 01    채치수  북산고  3.0  197.0      Python
# 02    정대만  북산고  3.0  184.0        Java
# 03    송태섭  북산고  3.0  168.0  Javascript
# 04    서태웅  북산고  1.0  187.0        Java
# 05    강백호  북산고  1.0  188.0         NaN
# 06    변덕규  능남고  3.0  202.0           C
# 07    황태산  능남고  2.0  188.0      Python
# 08    윤대협  능남고  2.0  190.0          C#
# 10    홍길동  NaN  NaN    NaN         NaN

# %%
df2
# Out:
#        이름   학교   학년      키        SW특기
# 지원번호
# 01    채치수  북산고  3.0  197.0      Python
# 02    정대만  북산고  3.0  184.0        Java
# 03    송태섭  북산고  3.0  168.0  Javascript
# 04    서태웅  북산고  1.0  187.0        Java
# 05    강백호  북산고  1.0  188.0         NaN
# 06    변덕규  능남고  3.0  202.0           C
# 07    황태산  능남고  2.0  188.0      Python
# 08    윤대협  능남고  2.0  190.0          C#
# 10    홍길동  NaN  NaN    NaN         NaN

# %%
new_no = str(int(df2.index.max()) + 1)
new_no
# Out:
# '11'

# %%
df2.loc[new_no, '이름'] = '강감찬'
df2
# Out:
#        이름   학교   학년      키        SW특기
# 지원번호
# 01    채치수  북산고  3.0  197.0      Python
# 02    정대만  북산고  3.0  184.0        Java
# 03    송태섭  북산고  3.0  168.0  Javascript
# 04    서태웅  북산고  1.0  187.0        Java
# 05    강백호  북산고  1.0  188.0         NaN
# 06    변덕규  능남고  3.0  202.0           C
# 07    황태산  능남고  2.0  188.0      Python
# 08    윤대협  능남고  2.0  190.0          C#
# 10    홍길동  NaN  NaN    NaN         NaN
# 11    강감찬  NaN  NaN    NaN         NaN

# %%
score1 = pd.read_csv('data/score.csv', index_col='지원번호')
score1
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df_info = score1[['이름', '학교', '키', 'SW특기']]
df_info
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1번    채치수  북산고  197      Python
# 2번    정대만  북산고  184        Java
# 3번    송태섭  북산고  168  Javascript
# 4번    서태웅  북산고  187         NaN
# 5번    강백호  북산고  188         NaN
# 6번    변덕규  능남고  202           C
# 7번    황태산  능남고  188      PYTHON
# 8번    윤대협  능남고  190          C#

# %%
info = df_info.copy()
info
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1번    채치수  북산고  197      Python
# 2번    정대만  북산고  184        Java
# 3번    송태섭  북산고  168  Javascript
# 4번    서태웅  북산고  187         NaN
# 5번    강백호  북산고  188         NaN
# 6번    변덕규  능남고  202           C
# 7번    황태산  능남고  188      PYTHON
# 8번    윤대협  능남고  190          C#

# %%
info.reset_index(inplace=True)
info
# Out:
#   지원번호   이름   학교    키        SW특기
# 0   1번  채치수  북산고  197      Python
# 1   2번  정대만  북산고  184        Java
# 2   3번  송태섭  북산고  168  Javascript
# 3   4번  서태웅  북산고  187         NaN
# 4   5번  강백호  북산고  188         NaN
# 5   6번  변덕규  능남고  202           C
# 6   7번  황태산  능남고  188      PYTHON
# 7   8번  윤대협  능남고  190          C#

# %% [markdown]
# change_no 함수 적용

# %%
info['지원번호'] = info['지원번호'].apply(change_no)
info.set_index('지원번호', inplace=True)
info
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 01    채치수  북산고  197      Python
# 02    정대만  북산고  184        Java
# 03    송태섭  북산고  168  Javascript
# 04    서태웅  북산고  187         NaN
# 05    강백호  북산고  188         NaN
# 06    변덕규  능남고  202           C
# 07    황태산  능남고  188      PYTHON
# 08    윤대협  능남고  190          C#

# %%
info.to_csv('data/학생정보.csv')

# %%
cols = info.columns
index = info.index
cols, index
# Out:
# (Index(['이름', '학교', '키', 'SW특기'], dtype='object'),
#  Index(['01', '02', '03', '04', '05', '06', '07', '08'], dtype='object', name='지원번호'))

# %%
info = pd.read_csv('data/학생정보.csv', index_col='지원번호')
info.drop(index=3)
# Out:
#        이름   학교    키    SW특기
# 지원번호
# 1     채치수  북산고  197  Python
# 2     정대만  북산고  184    Java
# 4     서태웅  북산고  187     NaN
# 5     강백호  북산고  188     NaN
# 6     변덕규  능남고  202       C
# 7     황태산  능남고  188  PYTHON
# 8     윤대협  능남고  190      C#
# 9     홍길동  NaN    0     NaN

# %%
cols = info.columns
info.index
cols, index
# Out:
# (Index(['이름', '학교', '키', 'SW특기'], dtype='object'),
#  Index(['01', '02', '03', '04', '05', '06', '07', '08'], dtype='object', name='지원번호'))

# %%
for idx in info.index:
    row = info.loc[idx]
    print(f'지원번호:{idx}', end='  ')
    for col in cols:
        print(f'{col}:{row[col]}', end='  ')
    print()
    print('-' * 50)
# Out:
# 지원번호:1  이름:채치수  학교:북산고  키:197  SW특기:Python
# --------------------------------------------------
# 지원번호:2  이름:정대만  학교:북산고  키:184  SW특기:Java
# --------------------------------------------------
# 지원번호:3  이름:송태섭  학교:북산고  키:168  SW특기:Javascript
# --------------------------------------------------
# 지원번호:4  이름:서태웅  학교:북산고  키:187  SW특기:nan
# --------------------------------------------------
# 지원번호:5  이름:강백호  학교:북산고  키:188  SW특기:nan
# --------------------------------------------------
# 지원번호:6  이름:변덕규  학교:능남고  키:202  SW특기:C
# --------------------------------------------------
# 지원번호:7  이름:황태산  학교:능남고  키:188  SW특기:PYTHON
# --------------------------------------------------
# 지원번호:8  이름:윤대협  학교:능남고  키:190  SW특기:C#
# --------------------------------------------------

# %%
info
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1     채치수  북산고  197      Python
# 2     정대만  북산고  184        Java
# 3     송태섭  북산고  168  Javascript
# 4     서태웅  북산고  187         NaN
# 5     강백호  북산고  188         NaN
# 6     변덕규  능남고  202           C
# 7     황태산  능남고  188      PYTHON
# 8     윤대협  능남고  190          C#

# %%
new_no = info.index.max()+1
info.loc[new_no, '이름'] = '홍길동'
info
# Out:
#        이름   학교      키        SW특기
# 지원번호
# 1     채치수  북산고  197.0      Python
# 2     정대만  북산고  184.0        Java
# 3     송태섭  북산고  168.0  Javascript
# 4     서태웅  북산고  187.0         NaN
# 5     강백호  북산고  188.0         NaN
# 6     변덕규  능남고  202.0           C
# 7     황태산  능남고  188.0      PYTHON
# 8     윤대협  능남고  190.0          C#
# 9     홍길동  NaN    NaN         NaN
# 10    홍길동  NaN    NaN         NaN

# %%
idxs=info.index
idxs
# Out:
# Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='지원번호')

# %%
no = 1
if no in idxs:
    row = info.loc[no]
    for col in cols:
        print(f'{col}:{row[col]}')
else:
    print('없다')
# Out:
# 이름:채치수
# 학교:북산고
# 키:197
# SW특기:Python

# %%
info
# Out:
#        이름   학교    키        SW특기
# 지원번호
# 1     채치수  북산고  197      Python
# 2     정대만  북산고  184        Java
# 3     송태섭  북산고  168  Javascript
# 4     서태웅  북산고  187         NaN
# 5     강백호  북산고  188         NaN
# 6     변덕규  능남고  202           C
# 7     황태산  능남고  188      PYTHON
# 8     윤대협  능남고  190          C#
# 9     홍길동  NaN    0         NaN

# %%
info.fillna('', inplace=True)
word = '태'
filt = info['이름'].str.contains(word)
search = info[filt]
idxs = search.index
if len(idxs) == 0:
    print('없음')
else:
    for idx in idxs:
        row = info.loc[idx]
        print(f'지원번호:{idx}', end=' ')
        for col in cols:
            print(f'{col}:{row[col]}', end=' ')
        print()
        print('-'*50)
# Out:
# 지원번호:3 이름:송태섭 학교:북산고 키:168 SW특기:Javascript
# --------------------------------------------------
# 지원번호:4 이름:서태웅 학교:북산고 키:187 SW특기:
# --------------------------------------------------
# 지원번호:7 이름:황태산 학교:능남고 키:188 SW특기:PYTHON
# --------------------------------------------------
